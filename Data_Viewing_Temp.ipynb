# %%
import pandas as pd

# %%
crime_data = pd.read_csv("Copy of Table_8_Offenses_Known_to_Law_Enforcement_by_State_by_City_2022.csv")
crime_data.head()
# Out:
#                              Table 8  Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0  Offenses Known to Law Enforcement         NaN         NaN             NaN
# 1             by State by City, 2022         NaN         NaN             NaN
# 2                              State        City  Population  Violent\ncrime
# 3                            ALABAMA   Abbeville       2,390              13
# 4                                NaN  Adamsville       4,233              19
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                     NaN        NaN        NaN
# 1                                     NaN        NaN        NaN
# 2  Murder and\nnonnegligent\nmanslaughter       Rape    Robbery
# 3                                       0          0          0
# 4                                       1          0          0
#
#             Unnamed: 7       Unnamed: 8 Unnamed: 9      Unnamed: 10  \
# ...
