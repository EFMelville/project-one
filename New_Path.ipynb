# %%
# Dependencies.
import pandas as pd
from pathlib import Path

# %%
# Establish file paths for csv files.
csv_path_5 = Path("Resources_2020/NIBRS_ARRESTEE.csv")
csv_path_18 = Path("Resources_2020/NIBRS_OFFENDER.csv")
csv_path_19 = Path("Resources_2020/NIBRS_OFFENSE.csv")
csv_path_20 = Path("Resources_2020/NIBRS_OFFENSE_TYPE.csv")
csv_path_23 = Path("Resources_2020/NIBRS_PROPERTY.csv")
csv_path_30 = Path("Resources_2020/NIBRS_VICTIM.csv")

# %%
# Read in the csv files for manipulation.
csv_5 = pd.read_csv(csv_path_5)
csv_18 = pd.read_csv(csv_path_18)
csv_19 = pd.read_csv(csv_path_19)
csv_20 = pd.read_csv(csv_path_20)
csv_23 = pd.read_csv(csv_path_23)
csv_30 = pd.read_csv(csv_path_30)

# %%
Incident_ID = pd.merge(csv_5, csv_19, on = "INCIDENT_ID", how = "outer")
Incident_ID_2 = pd.merge(Incident_ID, csv_18, on = "INCIDENT_ID", how = "inner")
Unique = len(Incident_ID_2["INCIDENT_ID"].unique())
Unique
# Out:
# 409541

# %%
Incident_ID_2.shape
# Out:
# (643703, 35)

# %%
csv_20 = csv_20[["OFFENSE_TYPE_ID", "OFFENSE_CATEGORY_NAME"]]
#csv_20 = csv_20.set_index("OFFENSE_TYPE_ID")

# %%
csv_20.dtypes
# Out:
# OFFENSE_TYPE_ID           int64
# OFFENSE_CATEGORY_NAME    object
# dtype: object

# %%
csv_20.loc[csv_20["OFFENSE_TYPE_ID"] == 58, "OFFENSE_CATEGORY_NAME"]
# Out:
# 0    Larceny/Theft Offenses
# Name: OFFENSE_CATEGORY_NAME, dtype: object

# %%
def get_offense(ID):
    return csv_20.loc[csv_20["OFFENSE_TYPE_ID"] == ID, "OFFENSE_CATEGORY_NAME"]

# %%
Incident_ID_2["OFFENSE_TYPE"] = ""
for index, row in Incident_ID_2.iterrows():
    Incident_ID_2.loc[index, "OFFENSE_TYPE"] = (get_offense(row["OFFENSE_TYPE_ID_y"]).values[0])

# %%
 Incident_ID_2.loc[0, "OFFENSE_TYPE_ID_y"]
# Out:
# 16

# %%
Incident_ID_2
# Out:
#         DATA_YEAR_x  ARRESTEE_ID  INCIDENT_ID  ARRESTEE_SEQ_NUM ARREST_DATE  \
# 0            2020.0   36471702.0    119544948               1.0   01-JAN-20
# 1            2020.0   36471705.0    119537395               1.0   04-JAN-20
# 2            2020.0   36471705.0    119537395               1.0   04-JAN-20
# 3            2020.0   36471785.0    119545072               1.0   04-JAN-20
# 4            2020.0   36471785.0    119545072               1.0   04-JAN-20
# ...             ...          ...          ...               ...         ...
# 643698          NaN          NaN    126868995               NaN         NaN
# 643699          NaN          NaN    126869007               NaN         NaN
# 643700          NaN          NaN    126869010               NaN         NaN
# 643701          NaN          NaN    126869013               NaN         NaN
# 643702          NaN          NaN    126869017               NaN         NaN
#
#         ARREST_TYPE_ID MULTIPLE_INDICATOR  OFFENSE_TYPE_ID_x  AGE_ID_x  \
# 0                  1.0                  N               16.0       5.0
# 1                  1.0                  N               23.0       5.0
# 2                  1.0                  N               23.0       5.0
# 3                  1.0                  N               16.0       5.0
# 4                  1.0                  N               16.0       5.0
# ...                ...                ...                ...       ...
# 643698             NaN                NaN                NaN       NaN
# 643699             NaN                NaN                NaN       NaN
# 643700             NaN                NaN                NaN       NaN
# 643701             NaN                NaN                NaN       NaN
# 643702             NaN                NaN                NaN       NaN
#
#         AGE_NUM_x  ... OFFENDER_ID  OFFENDER_SEQ_NUM  AGE_ID_y AGE_NUM_y  \
# 0            64.0  ...   135864048                 1       5.0      64.0
# 1            40.0  ...   135864055                 1       5.0      40.0
# 2            40.0  ...   135864055                 1       5.0      40.0
# 3            42.0  ...   135864186                 1       5.0      42.0
# 4            42.0  ...   135864186                 1       5.0      42.0
# ...           ...  ...         ...               ...       ...       ...
# 643698        NaN  ...   144182038                 1       4.0       NaN
# 643699        NaN  ...   144185681                 0       NaN       NaN
# 643700        NaN  ...   144185689                 1       5.0      25.0
# 643701        NaN  ...   144182058                 1       5.0      40.0
# 643702        NaN  ...   144185701                 1       5.0      30.0
#
#        SEX_CODE_y  RACE_ID_y  ETHNICITY_ID_y  AGE_RANGE_LOW_NUM_y  \
# 0               M        1.0             2.0                 64.0
# 1               M        1.0             2.0                 40.0
# 2               M        1.0             2.0                 40.0
# 3               F        1.0             2.0                 42.0
# 4               F        1.0             2.0                 42.0
# ...           ...        ...             ...                  ...
# 643698          M        0.0             3.0                  NaN
# 643699        NaN        NaN             NaN                  NaN
# 643700          F        2.0             2.0                 25.0
# 643701          M        1.0             2.0                 40.0
# 643702          M        2.0             3.0                 30.0
#
#         AGE_RANGE_HIGH_NUM_y            OFFENSE_TYPE
# 0                        0.0  Drug/Narcotic Offenses
# 1                        0.0  Larceny/Theft Offenses
# 2                        0.0  Drug/Narcotic Offenses
# 3                        0.0  Drug/Narcotic Offenses
# 4                        0.0  Drug/Narcotic Offenses
# ...                      ...                     ...
# 643698                   NaN  Larceny/Theft Offenses
# 643699                   NaN  Larceny/Theft Offenses
# 643700                   0.0        Assault Offenses
# 643701                   0.0        Assault Offenses
# 643702                   0.0  Larceny/Theft Offenses
#
# [643703 rows x 36 columns]
