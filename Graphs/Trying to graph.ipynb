# %%
# %matplotlib notebook

# %%
# Dependencies.
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
csv_path_2015 = Path("Data_Ref_2015.csv")
csv_path_2017 = Path("Data_Ref_2017.csv")
csv_path_2018 = Path("Data_Ref_2018.csv")
csv_path_2020 = Path("Data_Ref_2020.csv")
csv_path_2022 = Path("Data_Ref_2022.csv")

# %%
low_memory=False
CD15 = pd.read_csv(csv_path_2015)
CD17 = pd.read_csv(csv_path_2017)
CD18 = pd.read_csv(csv_path_2018)
CD20 = pd.read_csv(csv_path_2020)
CD22 = pd.read_csv(csv_path_2022)
# Out:
# /var/folders/mk/y4qry2pd21j2kpz277dxqgjm0000gn/T/ipykernel_49083/132651849.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   CD22 = pd.read_csv(csv_path_2022)

# %%
CD22["incident_id"] = CD22["incident_id"].astype(np.int64)

# %%
# Isolate number of unique incident ID's for reference.
Incidents15 = len(CD15["incident_id"].unique())
Incidents17 = len(CD17["INCIDENT_ID"].unique())
Incidents18 = len(CD18["INCIDENT_ID"].unique())
Incidents20 = len(CD20["INCIDENT_ID"].unique())
Incidents22 = len(CD22["incident_id"].unique())
Incident_Master = pd.DataFrame({"Year":[2015, 2017, 2018, 2020, 2022], 
                   "Incidents":[Incidents15, Incidents17, Incidents18, Incidents20, Incidents22]})
Incident_Master
# Out:
#    Year  Incidents
# 0  2015     457238
# 1  2017     409541
# 2  2018     461161
# 3  2020     409541
# 4  2022     402260

# %%
Offenses15 = len(CD15["offense_id"].unique())
Offenses17 = len(CD17["OFFENSE_ID"].unique())
Offenses18 = len(CD18["OFFENSE_ID"].unique())
Offenses20 = len(CD20["OFFENSE_ID"].unique())
Offenses22 = len(CD22["offense_id"].unique())
Offenses_Master = pd.DataFrame({"Year":[2015, 2017, 2018, 2020, 2022], 
                   "Offenses":[Offenses15, Offenses17, Offenses18, Offenses20, Offenses22]})
Offenses_Master
# Out:
#    Year  Offenses
# 0  2015    510923
# 1  2017    473941
# 2  2018    527986
# 3  2020    473941
# 4  2022    467550

# %%
Offenses_Master.plot.line(y = "Offenses", x = "Year", title = "Offenses Per Year")
plt.xlabel("Year")
plt.ylabel("Offenses")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Offenses_Master.plot.bar(y = "Offenses", x = "Year", title = "Offenses Per Year")
plt.xlabel("Year")
plt.ylabel("Offenses")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Race15 = CD15["race"].value_counts()
Race17 = CD17["RACE"].value_counts()
Race18 = CD18["RACE"].value_counts()
Race20 = CD20["RACE"].value_counts()
Race22 = CD22["race"].value_counts()
Race_Master = pd.DataFrame({
    2015:Race15, 
    2017:Race17,
    2018:Race18, 
    2020:Race20, 
    2022:Race22
}).fillna(0)
Race_Master
# Out:
#                                                2015      2017      2018  \
# American Indian or Alaska Native              633.0     779.0     723.0
# Asian                                        2804.0    1480.0    1962.0
# Black or African American                  220494.0  206174.0  238534.0
# Native Hawaiian or Other Pacific Islander     205.0     301.0     334.0
# Not Specified                                   0.0       0.0       0.0
# Unknown                                    174195.0  158937.0  170712.0
# White                                      309963.0  276032.0  327807.0
#
#                                                2020    2022
# American Indian or Alaska Native              779.0     724
# Asian                                        1480.0    1673
# Black or African American                  206174.0  203507
# Native Hawaiian or Other Pacific Islander     301.0     526
# Not Specified                                   0.0  101653
# Unknown                                    158937.0   60545
# White                                      276032.0  243526

# %%
Race_Master.T.plot.area(stacked = False)
plt.legend(loc = "lower left")
plt.xlabel("Year")
plt.ylabel("Offenses")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Sex15 = CD15["sex_code_y"].value_counts()
Sex17 = CD17["SEX_CODE_y"].value_counts()
Sex18 = CD18["SEX_CODE_y"].value_counts()
Sex20 = CD20["SEX_CODE_y"].value_counts()
Sex22 = CD22["sex_code_y"].value_counts()
Sex_Master = pd.DataFrame({
    2015:Sex15, 
    2017:Sex17,
    2018:Sex18, 
    2020:Sex20, 
    2022:Sex22
}).fillna(0)
Sex_Master = Sex_Master.drop(["X"])
Sex_Master
# Out:
#        2015      2017      2018      2020    2022
# F  167089.0  151709.0  181318.0  151709.0  138032
# M  374854.0  341703.0  395638.0  341703.0  320550
# U   71190.0   92652.0  105066.0   92652.0   51919

# %%
x_axis = [2015, 2017, 2018, 2020, 2022]
points_M = [374854, 341703, 395638, 341703, 320550]
points_F = [167089, 151709, 181318, 151709, 138032]
points_U = [71190, 92652, 105066, 92652, 51919]
male, = plt.plot(x_axis, points_M, marker = "o", color = "blue", linewidth = 3, label = "Male")
female, = plt.plot(x_axis, points_F, marker = "^", color = "red", linewidth = 2, label = "Female")
unknown, = plt.plot(x_axis, points_U, marker = "s", color = "orange", linewidth = 1, label = "Unknown")

# %%
Location15 = CD15["location_name"].value_counts()
Location17 = CD17["LOCATION_NAME"].value_counts()
Location18 = CD18["LOCATION_NAME"].value_counts()
Location20 = CD20["LOCATION_NAME"].value_counts()
Location22 = CD22["location_name"].value_counts()
Location_Master = pd.DataFrame({
    2015:Location15, 
    2017:Location17,
    2018:Location18, 
    2020:Location20, 
    2022:Location22
}).fillna(0)
Location_Master
# Out:
#                                                    2015      2017      2018  \
# ATM Separate from Bank                            565.0     475.0     927.0
# Abandoned/Condemned Structure                     945.0     729.0     654.0
# Air/Bus/Train Terminal                            951.0     642.0    1050.0
# Amusement Park                                    132.0     243.0     389.0
# Arena/Stadium/Fairgrounds/Coliseum                465.0     264.0     541.0
# Auto Dealership New/Used                         1688.0    2455.0    2022.0
# Bank/Savings and Loan                            6200.0    4437.0    6324.0
# Bar/Nightclub                                    3896.0    2496.0    3417.0
# Camp/Campground                                   600.0     592.0     624.0
# Church Synagogue/Temple                          2356.0       0.0       0.0
# Church/Synagogue/Temple/Mosque                      0.0    2199.0    2448.0
# Commercial/Office Building                       8617.0    7043.0    7915.0
# Community Center                                  175.0     504.0     346.0
# Construction Site                                1732.0    2125.0    2436.0
# Convenience Store                               18303.0   24239.0   24767.0
# Daycare Facility                                  389.0     229.0     303.0
# Department/Discount Store                       53863.0   38149.0   48974.0
# Dock/Wharf/Freight/Modal Terminal                 328.0     397.0     403.0
# Drug Store/Doctor's Office/Hospital                 0.0    4498.0    5576.0
# Drug Store/Dr. s Office/Hospital                 6265.0       0.0       0.0
# Farm Facility                                     626.0     528.0     628.0
# Field/Woods                                      3649.0    2778.0    3358.0
# Gambling Facility/Casino/Race Track               850.0       2.0      28.0
# Government/Public Building                       4590.0    2779.0    3784.0
# Grocery/Supermarket                             13006.0   12714.0   14593.0
# Highway/Road/Alley/Street/Sidewalk                  0.0  111064.0  128842.0
# Highway/Road/Ally                              108379.0       0.0       0.0
# Hotel/Motel/Etc.                                14679.0   15534.0   15887.0
# Industrial Site                                   765.0     736.0     824.0
# Jail/Prison                                      4519.0       0.0       0.0
# Jail/Prison/Penitentiary/Corrections Facility       0.0    3525.0    5079.0
# Lake/Waterway                                     799.0       0.0       0.0
# Lake/Waterway/Beach                                 0.0     529.0     650.0
# Liquor Store                                      922.0    1183.0     865.0
# Military Installation                              21.0      12.0      36.0
# Other/Unknown                                   17943.0   16664.0   17417.0
# Park/Playground                                  4926.0    3410.0    4575.0
# Parking Lot/Garage                              66804.0       0.0       0.0
# Parking/Drop Lot/Garage                             0.0   73234.0   79045.0
# Rental Stor. Facil.                              1898.0       0.0       0.0
# Rental Storage Facility                             0.0    3020.0    2246.0
# Residence/Home                                 314460.0  268769.0  302293.0
# Rest Area                                          78.0     151.0      78.0
# Restaurant                                       9784.0    8772.0   11711.0
# School-College/University                        1998.0    1074.0    2454.0
# School-Elementary/Secondary                     11948.0    5801.0   13166.0
# School/College                                      0.0       6.0      21.0
# Service/Gas Station                              5634.0    7165.0    6947.0
# Shelter-Mission/Homeless                          228.0     276.0     277.0
# Shopping Mall                                    1547.0    1865.0    2485.0
# Specialty Store                                 10767.0   10396.0   13665.0
# Tribal Lands                                        4.0       0.0       2.0
#
#                                                    2020      2022
# ATM Separate from Bank                            475.0     376.0
# Abandoned/Condemned Structure                     729.0     494.0
# Air/Bus/Train Terminal                            642.0    1408.0
# Amusement Park                                    243.0     370.0
# Arena/Stadium/Fairgrounds/Coliseum                264.0     426.0
# Auto Dealership New/Used                         2455.0    2371.0
# Bank/Savings and Loan                            4437.0    5750.0
# Bar/Nightclub                                    2496.0    4012.0
# Camp/Campground                                   592.0     599.0
# Church Synagogue/Temple                             0.0       0.0
# Church/Synagogue/Temple/Mosque                   2199.0    2040.0
# Commercial/Office Building                       7043.0    7985.0
# Community Center                                  504.0     659.0
# Construction Site                                2125.0    2232.0
# Convenience Store                               24239.0   19705.0
# Daycare Facility                                  229.0     236.0
# Department/Discount Store                       38149.0   31910.0
# Dock/Wharf/Freight/Modal Terminal                 397.0     501.0
# Drug Store/Doctor's Office/Hospital              4498.0    4830.0
# Drug Store/Dr. s Office/Hospital                    0.0       0.0
# Farm Facility                                     528.0     360.0
# Field/Woods                                      2778.0    2238.0
# Gambling Facility/Casino/Race Track                 2.0       7.0
# Government/Public Building                       2779.0    2707.0
# Grocery/Supermarket                             12714.0   10426.0
# Highway/Road/Alley/Street/Sidewalk             111064.0  108745.0
# Highway/Road/Ally                                   0.0       0.0
# Hotel/Motel/Etc.                                15534.0   12966.0
# Industrial Site                                   736.0     939.0
# Jail/Prison                                         0.0       0.0
# Jail/Prison/Penitentiary/Corrections Facility    3525.0    3878.0
# Lake/Waterway                                       0.0       0.0
# Lake/Waterway/Beach                               529.0     391.0
# Liquor Store                                     1183.0    1248.0
# Military Installation                              12.0      11.0
# Other/Unknown                                   16664.0   20938.0
# Park/Playground                                  3410.0    4021.0
# Parking Lot/Garage                                  0.0       0.0
# Parking/Drop Lot/Garage                         73234.0   73621.0
# Rental Stor. Facil.                                 0.0       0.0
# Rental Storage Facility                          3020.0    2698.0
# Residence/Home                                 268769.0  235126.0
# Rest Area                                         151.0     189.0
# Restaurant                                       8772.0    9507.0
# School-College/University                        1074.0    1349.0
# School-Elementary/Secondary                      5801.0   14821.0
# School/College                                      6.0     113.0
# Service/Gas Station                              7165.0    6272.0
# Shelter-Mission/Homeless                          276.0     463.0
# Shopping Mall                                    1865.0    2074.0
# Specialty Store                                 10396.0   11132.0
# Tribal Lands                                        0.0      10.0

# %%
colors = ["red", 
          "black", 
          "sienna", 
          "darkorange", 
          "khaki", 
          "olivedrab", 
          "chartreuse", 
          "crimson", 
          "rebeccapurple", 
          "cornflowerblue", 
          "blue", 
          "blueviolet", 
          "deeppink", 
          "thistle", 
          "lime", 
          "aqua", 
          "dodgerblue", 
          "darkgreen", 
          "lightslategrey", 
          "maroon", 
          "darksalmon", 
          "darkseagreen", 
          "burlywood", 
          "ghostwhite", 
          "indigo", 
          "teal", 
          "lemonchiffon", 
          "yellowgreen", 
          "orangered", 
          "aquamarine", 
          "plum", 
          "gray", 
          "lightpink", 
          "deepskyblue", 
          "goldenrod", 
          "firebrick", 
          "silver", 
          "hotpink", 
          "mediumturquoise", 
          "tomato", 
           "paleturquoise", 
          "peru", 
          "lightgoldenrodyellow", 
          "lavenderblush", 
          "mediumaquamarine", 
          "cadetblue", 
          "mistyrose", 
          "green", 
          "royalblue", 
          "burlywood", 
          "yellow", 
          "pink"
         ]
Location_Master.T.plot(subplots = True, figsize = (10, 50), color = colors)
plt.legend(loc = "best")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
Crime_types15 = CD15["offense_type"].value_counts()
Crime_types17 = CD17["OFFENSE_TYPE"].value_counts()
Crime_types18 = CD18["OFFENSE_TYPE"].value_counts()
Crime_types20 = CD20["OFFENSE_TYPE"].value_counts()
Crime_types22 = CD22["offense_type"].value_counts()
Types_Master = pd.DataFrame({2015:Crime_types15,
                             2017:Crime_types17,
                             2018:Crime_types18,
                             2020:Crime_types20,
                             2022:Crime_types22
                             }).fillna(0)
Types_Master
# Out:
#                                               2015    2017    2018    2020  \
# Animal Cruelty                                 0.0     543     568     543
# Arson                                       1355.0    1133    1003    1133
# Assault Offenses                          151863.0  138125  148783  138125
# Bribery                                       25.0      34      25      34
# Burglary/Breaking & Entering               54426.0   32532   41651   32532
# Counterfeiting/Forgery                      9574.0    7081    9954    7081
# Destruction/Damage/Vandalism of Property   62541.0   57165   57159   57165
# Drug/Narcotic Offenses                    149155.0  138411  179401  138411
# Embezzlement                                3445.0    1842    3233    1842
# Extortion/Blackmail                          177.0     552     470     552
# Fraud Offenses                             34423.0   30559   36789   30559
# Gambling Offenses                           1485.0     110     418     110
# Homicide Offenses                            830.0    1068     946    1068
# Human Trafficking                             63.0      69      47      69
# Kidnapping/Abduction                        2313.0    2355    2056    2355
# Larceny/Theft Offenses                    176087.0  155711  177713  155711
# Motor Vehicle Theft                        15759.0   27467   26387   27467
# Pornography/Obscene Material                 982.0    1000    1224    1000
# Prostitution Offenses                       2209.0     609     967     609
# Robbery                                    15421.0   11719   15553   11719
# Sex Offenses                                6228.0    5054    5951    5054
# Sex Offenses, Non-forcible                     0.0     461     427     461
# Stolen Property Offenses                    2044.0    5376    4906    5376
# Weapon Law Violations                      17889.0   24727   24441   24727
#
#                                             2022
# Animal Cruelty                               829
# Arson                                       1009
# Assault Offenses                          135111
# Bribery                                       42
# Burglary/Breaking & Entering               27391
# Counterfeiting/Forgery                      7068
# Destruction/Damage/Vandalism of Property   52722
# Drug/Narcotic Offenses                    129188
# Embezzlement                                2391
# Extortion/Blackmail                          948
# Fraud Offenses                             31230
# Gambling Offenses                            562
# Homicide Offenses                            912
# Human Trafficking                            104
# Kidnapping/Abduction                        2048
# Larceny/Theft Offenses                    139520
# Motor Vehicle Theft                        31341
# Pornography/Obscene Material                1430
# Prostitution Offenses                        670
# Robbery                                     9008
# Sex Offenses                                5774
# Sex Offenses, Non-forcible                   323
# Stolen Property Offenses                    4704
# Weapon Law Violations                      27829
